# %% [markdown]
# # Inheritance
# - a class can inherit from other class
# - it improve code reuse
# - construcor ,attribute and method are inheritance to child class
# - parent class has no access to child class
# - child class methods overrides the parent class methods
#  - this is called method overriding
# - super() method is used to invoke parent class method and constructor

# %% [markdown]
# ## Single inheritance

# %%
class Person:
    def __init__(self,name):
        self.name=name
    def show(self):
        print(self.name+"is a python teacher")
class Professor(Person):
    def display(self):
        print("This is ",self.name)

# %%
per=Professor("Guido Rossum")

# %%
per.name
# Out:
# 'Guido Rossum'

# %%
per.show()
# Out:
# Guido Rossumis a python teacher

# %% [markdown]
# ## Multilevel inheritance

# %%
class Human:
    def __init__(self,name):
        self.name=name
    def show(self):
        print(self.name)
class Person(Human):
        pass
class Professor1(Person):
        pass

# %%
p=Professor1("abc")

# %%
p.name
# Out:
# 'abc'

# %% [markdown]
# ## Multiple inheritance

# %%
class Person:
    def __init__(self,name):
        self.name=name
    def show(self):
        print(self.name)
class Teacher:
        def credit(self):
            print("he teaches python")
class PythonProgrammer(Person,Teacher):
        pass

# %%
p1=PythonProgrammer("hi")

# %%
print(p1.credit())
# Out:
# he teaches python
# None
# hi

# %%
p1.name
# Out:
# 'hi'

# %% [markdown]
# ## Hiearchical inheritance

# %%
class Human:
    def __init__(self,name):
        self.name=name
    def show(self):
        print(self.name+" is a professor")
class pythonprogrammer(Human):
    pass
class javaprogrammer(Human):
    pass

# %%
p=pythonprogrammer("xyz")

# %%
p.show()
# Out:
# xyzis a professor

# %%
j=javaprogrammer("pqr")

# %%
j.show()
# Out:
# pqr is a professor

# %% [markdown]
# ## Constructor Overriding

# %%
class Father:
    def __init__(self):
        self.money=10000
        print("Father class Constr")
    def show(self):
        print("Father class method")
class Son(Father):
    def __init__(self):
        self.money=500
        self.car="BMW"
        print("son class Constr")
    def display(self):
        print("son class method")

# %%
s=Son()
# Out:
# son class Constr

# %%
s.money
# Out:
# 500

# %%
f=Father()
# Out:
# Father class Constr

# %%
f.money
# Out:
# 10000

# %% [markdown]
# ## `super() method`
# - if we write constructor in both parent and child class,the parent class constrc is not available in child class
# - `super()` method is used to call parent class from the child class

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("inside phone class")
        self.price=price
        self.brand=brand
        self.camera=camera
    def buy(self):
        print("Buying phone")
class SmartPhone(Phone):
    def buy(self):
        print("Buying a smartphone")
        super().buy()

# %%
s=SmartPhone(20000,'iphone',13)
# Out:
# inside phone class

# %% [markdown]
# ### another example

# %%
class Father:
    def __init__(self):
        self.money=10000
        print("Father class constructor")
    def show(self):
        print("Father class method")
class Son(Father):
    def __init__(self):
        super().__init__()
        print("son calss const")
    def display(self):
        print("son class method ")

# %%
s=Son()
# Out:
# Father class constructor
# son calss const

# %%
s.money
# Out:
# 10000

# %% [markdown]
# # Polymorphism
# - condition of occurence in diffrent forms
# - at operator level
# - at function level
# - at method level

# %%
class Car:
    def start(self):
        print("Engine started")
    def move(self):
        print("car is running")
    def stop(self):
        print("brake applied")
class Clock:
    def move(self):
        print("tic tic tic")
    def stop(self):
        print("clock stopped")
class Person:
    def move(self):
        print("person is moving")
    def stop(self):
        print("person stoped")

# %%
c= Car()
c1=Clock()
p=Person()

# %%
def dosomething(x):
    x.move()
    x.stop()

# %%
dosomething(c)
# Out:
# car is running
# brake applied

# %%
dosomething(c1)
# Out:
# tic tic tic
# clock stopped

# %%
dosomething(p)
# Out:
# person is moving
# person stoped

# %% [markdown]
# ## operator overloading

# %%
print(2+3)
print("2"+"3")
# Out:
# 5
# 23

# %% [markdown]
# ## Function overloading

# %%
print(len("python"))
print(len(["ver1","ver2","ver3"]))
print(len({"Creator":"aa","nationality":"dutch"}))
# Out:
# 6
# 3
# 2

# %% [markdown]
# ## Abstract class
# - a class derived from BAC class which belong to abc module is called abstract class in python
# - ABC class is known as meta class which means class that defines behaviour of other classes.
# - Abstarct class can have concreate and abstract methods
# - Abstract class needs to be extended and its methods implemented
# - one cannot create object of an abstract class

# %%
from abc import ABC,abstractmethod
class DefenceForce(ABC):
    def __init__(self):
        self.id=101
    @abstractmethod
    def area(self):
        pass
    def gun(self):
        print("the gun is ak47")

# %%
class Army(DefenceForce):
    def area(self):
        print("area is land",self.id)

# %%
a=Army()

# %%
a.area()
# Out:
# area is land 101

# %%
a.gun()
# Out:
# the gun is ak47

# %%
class Navy(DefenceForce):
    def area(self):
        print("area is sea",self.id)

# %%
n=Navy()

# %%
n.area()
# Out:
# area is sea 101

# %%
n.gun()
# Out:
# the gun is ak47

# %%
n.id
# Out:
# 101

# %% [markdown]
# ## Create an abstract class Shape with abstract method `calculate_area`. Create two class Rectangle  and  Circle inheriting from shape. Create two object of rectangle and circle and find the area of these objects

# %%
from abc import ABC,abstractmethod
import math
class Shape(ABC):
    @abstractmethod
    def calculate_area():
        pass

# %%
class Rectangle(Shape):
    def __init__(self,l,b):
        self.l=l
        self.b=b
    def calculate_area(self):
        print(self.l*self.b)

# %%
class Circle(Shape):
    def __init__(self,r):
        self.r=r
    def calculate_area(self):
        print(math.pi*(self.r**2))

# %%
r=Rectangle(10,20)
r.calculate_area()
# Out:
# 200

# %%
c=Circle(10)
c.calculate_area()
# Out:
# 314.1592653589793

# %% [markdown]
# ### pb 632
# Implement the following hierarchy . The Book function has name, n (number of authors), authors (list of authors),
# publisher, ISBN, and year as its data members and the derived class has course as its data member. The derived class
# method overrides (extends) the methods of the base
# class.

# %%
class Book:
    def __init__(self,name,n,authors,publisher,ISBN,year):
        self.name=name
        self.n=n
        self.authors=authors
        self.publisher=publisher
        self.ISBN=ISBN
        self.year=year
    def display(self):
        print(self.name)
        print(self.n)
        print(self.authors)
        print(self.publisher)
        print(self.ISBN)
        print(self.year)
class derivedBook(Book):
        def __init__(self,name,n,authors,publisher,ISBN,year,course):
            super().__init__()
            self.course=course
        def display(self):
            #super().display
            print(self.name)
            print(self.n)
            print(self.authors)
            print(self.publisher)
            print(self.ISBN)
            print(self.year)

# %%
b=Book('name1',12,['aut1','aut2'],'pub1',2776,2006)

# %%
b.display()
# Out:
# name1
# 12
# ['aut1', 'aut2']
# pub1
# 2776
# 2006
